# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
input_csv = "sentiment_analysis.csv"  # path to results CSV
# === LOAD DATA ===
df = pd.read_csv(input_csv)
df.head()
# Out:
#                                     video_link gender news     video_id  \
# 0  https://www.youtube.com/watch?v=7LVSrTZDopM      m    n  7LVSrTZDopM
# 1  https://www.youtube.com/watch?v=7LVSrTZDopM      m    n  7LVSrTZDopM
# 2  https://www.youtube.com/watch?v=7LVSrTZDopM      m    n  7LVSrTZDopM
# 3  https://www.youtube.com/watch?v=7LVSrTZDopM      m    n  7LVSrTZDopM
# 4  https://www.youtube.com/watch?v=7LVSrTZDopM      m    n  7LVSrTZDopM
#
#                                          video_name       channel_name  \
# 0  Climate "Science" | Dr. Richard Lindzen | EP 320  Jordan B Peterson
# 1  Climate "Science" | Dr. Richard Lindzen | EP 320  Jordan B Peterson
# 2  Climate "Science" | Dr. Richard Lindzen | EP 320  Jordan B Peterson
# 3  Climate "Science" | Dr. Richard Lindzen | EP 320  Jordan B Peterson
# 4  Climate "Science" | Dr. Richard Lindzen | EP 320  Jordan B Peterson
#
#    subscribers    views  comments  likes  \
# 0      8830000  1432756      8332  39968
# 1      8830000  1432756      8332  39968
# 2      8830000  1432756      8332  39968
# 3      8830000  1432756      8332  39968
# 4      8830000  1432756      8332  39968
#
#                                         comment_text       comment_author  \
# 0  Note the Climate Change propaganda that YouTub...     @JordanBPeterson
# 1  Thank you Dr Peterson for inviting Dr Lindzen,...  @DanielleDurand-q6l
# 2  Dr Lindzin is stepping straight into the mista...   @riaanswiegers6628
# 3  Thank you! I'm considered a "science denier"  ...  @flameofthewest6196
# 4  Fairies will always make more money than scien...           @dickbrmly
#
#    comment_likes          comment_date sentiment  confidence
# 0           5648  2023-01-08T09:52:52Z  negative    0.835941
# 1              1  2025-10-17T11:56:05Z  positive    0.931553
# 2              0  2025-10-05T05:32:16Z  negative    0.681610
# 3              3  2025-09-22T19:57:39Z   neutral    0.552359
# 4              1  2025-09-17T12:39:56Z  negative    0.484183

# %%
# === MAP SENTIMENT TO NUMERIC VALUES ===
sentiment_map = {
    "positive": 1,
    "neutral": 0,
    "negative": -1
}
df["sentiment_score"] = df["sentiment"].map(sentiment_map)

# === COMPUTE AVERAGE SENTIMENT PER VIDEO ===
avg_sentiment = df.groupby("video_id").agg({
    "sentiment_score": "mean",
    "gender": "first",
    "news": "first",
    "channel_name": "first",
    "video_link": "first",
    "comments": "count"
}).reset_index()

avg_sentiment.rename(columns={"comments": "number_of_comments"}, inplace=True)

avg_sentiment.head()
# Out:
#       video_id  sentiment_score gender news       channel_name  \
# 0  0FmHqjx6ESQ        -0.516000      m    n          JRE Clips
# 1  15-QlH_VDaM        -0.340741      f    n    Bridget Phetasy
# 2  1LAyILmn2Hk        -0.162088      f    n           GEO GIRL
# 3  1dRgCsZ1q7g        -0.166000      m    n       vlogbrothers
# 4  2W3pxOYrxVw        -0.048295      m    n  Jordan B Peterson
#
#                                      video_link  number_of_comments
# 0  https://www.youtube.com/watch?v=0FmHqjx6ESQ                 1000
# 1  https://www.youtube.com/watch?v=15-QlH_VDaM                  270
# 2  https://www.youtube.com/watch?v=1LAyILmn2Hk                  364
# 3  https://www.youtube.com/watch?v=1dRgCsZ1q7g                 1000
# 4  https://www.youtube.com/watch?v=2W3pxOYrxVw                  704

# %%
female_count = (avg_sentiment['gender'] == 'f').sum()
print(f"Total rows with gender = 'f': {female_count}")

news_count = (avg_sentiment['news'] == 'y').sum()
print(f"Total rows with news = 'y': {news_count}")

print(f"Total rows: {avg_sentiment['video_id'].count()}")
# Out:
# Total rows with gender = 'f': 24
# Total rows with news = 'y': 10
# Total rows: 88

# %%
top_positive = avg_sentiment.sort_values("sentiment_score", ascending=False).head(10)
top_positive
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# Name: news, Length: 88, dtype: bool
